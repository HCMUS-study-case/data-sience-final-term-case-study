# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# ### Câu hỏi: Tháng nào trong năm có tổng biến động giá trị dương nhiều nhất, và âm nhiều nhất?
# Trả lời được câu hỏi này giúp chúng ta có thể dự đoán quy luật của năm 2023 dựa trên kết quả của năm 2022, để có thể có một cách đầu tư khôn ngoan (tháng nào dương nhiều nhất thì nên đầu tư, và ngược lại)

# %%
df_his=pd.read_csv("data-csv/historical_quotes.csv")
df_his['date']=pd.to_datetime(df_his['date'],format='%Y-%m-%d')
df_his.head(10)
# Out:
#    Unnamed: 0       date  open price  high price  low price  close price  \
# 0           0 2022-11-29        11.5        11.5       10.3         11.5
# 1           1 2022-11-28         8.7        10.5        8.7         10.5
# 2           2 2022-11-25         9.4         9.6        9.4          9.6
# 3           3 2022-11-24         8.0         8.8        7.4          8.8
# 4           4 2022-11-23         8.4         8.8        8.0          8.0
# 5           5 2022-11-22         8.2         8.4        8.0          8.4
# 6           6 2022-11-21         7.6         7.7        7.3          7.7
# 7           7 2022-11-18         6.7         7.0        6.0          7.0
# 8           8 2022-11-17         6.2         6.4        6.2          6.4
# 9           9 2022-11-16         4.9         5.9        4.9          5.9
#
#    AVG price  adjusted close price   volume  value fluctuation  \
# 0      11.23                  11.5  1589500                1.0
# 1      10.42                  10.5   103700                0.9
# 2       9.60                   9.6   289900                0.8
# 3       8.17                   8.8   751400                0.8
# 4       8.30                   8.0   642500               -0.4
# 5       8.35                   8.4  1137500                0.7
# 6       7.65                   7.7   410900                0.7
# 7       6.61                   7.0  1394200                0.6
# 8       6.36                   6.4   880900                0.5
# 9       5.19                   5.9   956200                0.5
#
#    rate fluctuation
# 0              9.52
# 1              9.38
# 2              9.09
# 3             10.00
# 4             -4.76
# 5              9.09
# 6             10.00
# 7              9.38
# 8              8.47
# 9              9.26

# %% [markdown]
# Lấy dữ liệu từ 1/1/2022 đến ngày hiện tại

# %%
first_day = np.datetime64("2022-01-01")
today = np.datetime64('today', 'D')
df_his_ques = df_his[df_his['date'].between(first_day, today)]
df_his_ques.head(30)
# Out:
#     Unnamed: 0       date  open price  high price  low price  close price  \
# 0            0 2022-11-29        11.5        11.5       10.3         11.5
# 1            1 2022-11-28         8.7        10.5        8.7         10.5
# 2            2 2022-11-25         9.4         9.6        9.4          9.6
# 3            3 2022-11-24         8.0         8.8        7.4          8.8
# 4            4 2022-11-23         8.4         8.8        8.0          8.0
# 5            5 2022-11-22         8.2         8.4        8.0          8.4
# 6            6 2022-11-21         7.6         7.7        7.3          7.7
# 7            7 2022-11-18         6.7         7.0        6.0          7.0
# 8            8 2022-11-17         6.2         6.4        6.2          6.4
# 9            9 2022-11-16         4.9         5.9        4.9          5.9
# 10          10 2022-11-15         5.9         5.9        5.4          5.4
# 11          11 2022-11-14         6.2         6.3        5.9          5.9
# 12          12 2022-11-11         6.8         7.1        6.1          6.5
# 13          13 2022-11-10         6.6         7.0        6.6          6.6
# 14          14 2022-11-09         7.1         7.7        7.0          7.3
# 15          15 2022-11-08         6.6         7.3        6.6          7.1
# 16          16 2022-11-07         8.1         8.2        7.3          7.3
# 17          17 2022-11-04         9.0         9.0        8.1          8.1
# 18          18 2022-11-03         9.1         9.3        8.9          9.0
# 19          19 2022-11-02         9.4         9.6        9.0          9.3
# 20          20 2022-11-01         9.0         9.8        9.0          9.2
# 21          21 2022-10-31        10.3        10.3        9.3          9.9
# 22          22 2022-10-28        10.4        10.6       10.0         10.2
# 23          23 2022-10-27         9.6        10.2        9.0         10.2
# 24          24 2022-10-26        10.4        10.4        9.0          9.4
# 25          25 2022-10-25         9.4        10.2        9.0         10.0
# 26          26 2022-10-24        10.9        10.9        9.9          9.9
# 27          27 2022-10-21        12.1        12.1       10.9         10.9
# 28          28 2022-10-20        12.1        12.5       11.9         12.1
# 29          29 2022-10-19        12.7        12.8       12.3         12.4
#
#     AVG price  adjusted close price   volume  value fluctuation  \
# 0       11.23                  11.5  1589500                1.0
# 1       10.42                  10.5   103700                0.9
# 2        9.60                   9.6   289900                0.8
# 3        8.17                   8.8   751400                0.8
# 4        8.30                   8.0   642500               -0.4
# 5        8.35                   8.4  1137500                0.7
# 6        7.65                   7.7   410900                0.7
# 7        6.61                   7.0  1394200                0.6
# 8        6.36                   6.4   880900                0.5
# 9        5.19                   5.9   956200                0.5
# 10       5.41                   5.4   506400               -0.5
# 11       6.03                   5.9   581500               -0.6
# 12       6.75                   6.5   983000               -0.1
# 13       6.66                   6.6   490200               -0.7
# 14       7.40                   7.3   469400                0.2
# 15       6.87                   7.1   561400               -0.2
# 16       7.49                   7.3   675800               -0.8
# 17       8.30                   8.1   940500               -0.9
# 18       9.07                   9.0   446500               -0.3
# 19       9.22                   9.3   322400                0.1
# 20       9.17                   9.2  1634800               -0.7
# 21       9.60                   9.9    98400               -0.3
# 22      10.36                  10.2   166700                0.0
# 23       9.70                  10.2   192900                0.8
# 24       9.31                   9.4   181100               -0.6
# 25       9.38                  10.0   366900                0.1
# 26      10.07                   9.9   204100               -1.0
# 27      11.25                  10.9   279300               -1.2
# 28      12.16                  12.1   139400               -0.3
# 29      12.50                  12.4   138100               -0.3
#
#     rate fluctuation
# 0               9.52
# 1               9.38
# 2               9.09
# 3              10.00
# 4              -4.76
# 5               9.09
# 6              10.00
# 7               9.38
# 8               8.47
# 9               9.26
# 10             -8.47
# 11             -9.23
# 12             -1.52
# 13             -9.59
# 14              2.82
# 15             -2.74
# 16             -9.88
# 17            -10.00
# 18             -3.23
# 19              1.09
# 20             -7.07
# 21             -2.94
# 22              0.00
# 23              8.51
# 24             -6.00
# 25              1.01
# 26             -9.17
# 27             -9.92
# 28             -2.42
# 29             -2.36

# %% [markdown]
# Hàm hỗ trợ lấy ngày đầu tiên, và ngày cuối cùng của 1 tháng

# %%
def getFirstLastDate(month):
    if month==1 or month ==3 or month == 5 or month == 7 or month == 8 or month == 10 or month == 12:
        last = 31
    elif month == 2:
        last = 28
    else:
        last = 30
    
    if month < 10:
        first_day_of_month = np.datetime64("2022-0{}-01".format(month))
        last_day_of_month = np.datetime64("2022-0{}-{}".format(month,last))
    else:
        first_day_of_month = np.datetime64("2022-{}-01".format(month))
        last_day_of_month = np.datetime64("2022-{}-{}".format(month,last))
    tuple_day = (first_day_of_month, last_day_of_month)
    return tuple_day

# %% [markdown]
# Tìm tháng có tổng biến động giá trị dương nhiều nhất, và âm nhiều nhất?

# %%
rate_fluctuation_month = []
rate_fluctuation = df_his_ques["rate fluctuation"]
date_array = df_his_ques["date"]

current_month = 1

while(current_month <= 12):
    tuple_day = getFirstLastDate(current_month)
    sub_df_his_ques = df_his_ques[df_his_ques['date'].between(tuple_day[0], tuple_day[1])]
    rate_sum = sum(sub_df_his_ques["rate fluctuation"])
    rate_fluctuation_month.append(rate_sum)
    current_month+=1
max_month = rate_fluctuation_month.index(max(rate_fluctuation_month)) + 1
min_month = rate_fluctuation_month.index(min(rate_fluctuation_month)) + 1

print("Tháng có sự biến động âm nhiều nhất: ", min_month)
print("Tháng có sự biến động dương nhiều nhất: ", max_month)
# Out:
# Tháng có sự biến động âm nhiều nhất:  10
# Tháng có sự biến động dương nhiều nhất:  8

# %% [markdown]
# - Qua kết quả rút ra ở trên, nhóm em nhận thấy trong 2022, tháng 8 là tháng có sự biến động giá cổ phiểu dương nhiều nhất, tức là giá cổ phiếu có xu hướng đi lên nhiều => Nhóm em quyết định đầu tư tất tay vào tháng 8 năm 2023, và sẽ bán trước tháng 10/2023, vì vào tháng 10, giá cổ phiếu có xu hướng giảm.
